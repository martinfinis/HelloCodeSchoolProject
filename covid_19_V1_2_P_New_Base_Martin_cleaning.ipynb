# %% [markdown]
# <a href="https://colab.research.google.com/github/martinfinis/HelloCodeSchoolProject/blob/master/covid_19_V1_2_P_New_Base_Martin_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import time

# %%
# mount google drive to access dataset food
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/

# !unzip '/content/drive/.shortcut-targets-by-id/1lp7vo6EG60jba1Gk_tuNpvDm7q5ZXlKX/Telecom_Specialization_ML3/Students/Peter_Christoph_Marko_Martin/data/archive.zip'
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   inflating: curated_data/curated_data/2COVID/P024_121.png
#   inflating: curated_data/curated_data/2COVID/P024_122.png
#   inflating: curated_data/curated_data/2COVID/P024_123.png
#   inflating: curated_data/curated_data/2COVID/P024_124.png
#   inflating: curated_data/curated_data/2COVID/P024_125.png
#   inflating: curated_data/curated_data/2COVID/P024_127.png
#   inflating: curated_data/curated_data/2COVID/P024_128.png
#   inflating: curated_data/curated_data/2COVID/P024_129.png
#   inflating: curated_data/curated_data/2COVID/P024_130.png
#   inflating: curated_data/curated_data/2COVID/P024_131.png
#   inflating: curated_data/curated_data/2COVID/P024_132.png
#   inflating: curated_data/curated_data/2COVID/P024_133.png
#   inflating: curated_data/curated_data/2COVID/P024_134.png
#   inflating: curated_data/curated_data/2COVID/P024_135.png
#   inflating: curated_data/curated_data/2COVID/P024_136.png
#   inflating: curated_data/curated_data/2COVID/P024_14.png
#   inflating: curated_data/curated_data/2COVID/P024_15.png
#   inflating: curated_data/curated_data/2COVID/P024_16.png
#   inflating: curated_data/curated_data/2COVID/P024_17.png
#   inflating: curated_data/curated_data/2COVID/P024_18.png
#   inflating: curated_data/curated_data/2COVID/P024_19.png
#   inflating: curated_data/curated_data/2COVID/P024_20.png
#   inflating: curated_data/curated_data/2COVID/P024_21.png
#   inflating: curated_data/curated_data/2COVID/P024_22.png
#   inflating: curated_data/curated_data/2COVID/P024_23.png
#   inflating: curated_data/curated_data/2COVID/P024_25.png
#   inflating: curated_data/curated_data/2COVID/P024_26.png
#   inflating: curated_data/curated_data/2COVID/P024_27.png
#   inflating: curated_data/curated_data/2COVID/P024_28.png
#   inflating: curated_data/curated_data/2COVID/P024_29.png
#   inflating: curated_data/curated_data/2COVID/P024_3.png
#   inflating: curated_data/curated_data/2COVID/P024_30.png
#   inflating: curated_data/curated_data/2COVID/P024_31.png
#   inflating: curated_data/curated_data/2COVID/P024_32.png
#   inflating: curated_data/curated_data/2COVID/P024_33.png
#   inflating: curated_data/curated_data/2COVID/P024_34.png
#   inflating: curated_data/curated_data/2COVID/P024_36.png
#   inflating: curated_data/curated_data/2COVID/P024_37.png
#   inflating: curated_data/curated_data/2COVID/P024_38.png
#   inflating: curated_data/curated_data/2COVID/P024_4.png
#   inflating: curated_data/curated_data/2COVID/P024_5.png
#   inflating: curated_data/curated_data/2COVID/P024_6.png
#   inflating: curated_data/curated_data/2COVID/P024_7.png
#   inflating: curated_data/curated_data/2COVID/P024_8.png
#   inflating: curated_data/curated_data/2COVID/P024_87.png
#   inflating: curated_data/curated_data/2COVID/P024_88.png
#   inflating: curated_data/curated_data/2COVID/P024_89.png
#   inflating: curated_data/curated_data/2COVID/P024_9.png
#   inflating: curated_data/curated_data/2COVID/P024_90.png
#   inflating: curated_data/curated_data/2COVID/P024_91.png
#   inflating: curated_data/curated_data/2COVID/P024_92.png
#   inflating: curated_data/curated_data/2COVID/P024_94.png
#   inflating: curated_data/curated_data/2COVID/P024_95.png
#   inflating: curated_data/curated_data/2COVID/P024_96.png
#   inflating: curated_data/curated_data/2COVID/P024_97.png
#   inflating: curated_data/curated_data/2COVID/P024_98.png
#   inflating: curated_data/curated_data/2COVID/P024_99.png
#   inflating: curated_data/curated_data/2COVID/P025_10.png
#   inflating: curated_data/curated_data/2COVID/P025_100.png
#   inflating: curated_data/curated_data/2COVID/P025_101.png
#   inflating: curated_data/curated_data/2COVID/P025_102.png
#   inflating: curated_data/curated_data/2COVID/P025_103.png
#   inflating: curated_data/curated_data/2COVID/P025_106.png
#   inflating: curated_data/curated_data/2COVID/P025_107.png
#   inflating: curated_data/curated_data/2COVID/P025_108.png
#   inflating: curated_data/curated_data/2COVID/P025_109.png
#   inflating: curated_data/curated_data/2COVID/P025_11.png
#   inflating: curated_data/curated_data/2COVID/P025_110.png
#   inflating: curated_data/curated_data/2COVID/P025_111.png
#   inflating: curated_data/curated_data/2COVID/P025_112.png
#   inflating: curated_data/curated_data/2COVID/P025_113.png
#   inflating: curated_data/curated_data/2COVID/P025_114.png
#   inflating: curated_data/curated_data/2COVID/P025_115.png
#   inflating: curated_data/curated_data/2COVID/P025_117.png
#   inflating: curated_data/curated_data/2COVID/P025_118.png
#   inflating: curated_data/curated_data/2COVID/P025_119.png
#   inflating: curated_data/curated_data/2COVID/P025_12.png
#   inflating: curated_data/curated_data/2COVID/P025_120.png
#   inflating: curated_data/curated_data/2COVID/P025_121.png
#   inflating: curated_data/curated_data/2COVID/P025_122.png
#   inflating: curated_data/curated_data/2COVID/P025_123.png
#   inflating: curated_data/curated_data/2COVID/P025_124.png
#   inflating: curated_data/curated_data/2COVID/P025_125.png
#   inflating: curated_data/curated_data/2COVID/P025_126.png
#   inflating: curated_data/curated_data/2COVID/P025_128.png
#   inflating: curated_data/curated_data/2COVID/P025_129.png
#   inflating: curated_data/curated_data/2COVID/P025_130.png
#   inflating: curated_data/curated_data/2COVID/P025_131.png
#   inflating: curated_data/curated_data/2COVID/P025_132.png
#   inflating: curated_data/curated_data/2COVID/P025_133.png
#   inflating: curated_data/curated_data/2COVID/P025_134.png
#   inflating: curated_data/curated_data/2COVID/P025_135.png
#   inflating: curated_data/curated_data/2COVID/P025_136.png
#   inflating: curated_data/curated_data/2COVID/P025_137.png
#   inflating: curated_data/curated_data/2COVID/P025_139.png
#   inflating: curated_data/curated_data/2COVID/P025_14.png
#   inflating: curated_data/curated_data/2COVID/P025_140.png
#   inflating: curated_data/curated_data/2COVID/P025_141.png
#   inflating: curated_data/curated_data/2COVID/P025_142.png
#   inflating: curated_data/curated_data/2COVID/P025_143.png
#   inflating: curated_data/curated_data/2COVID/P025_144.png
#   inflating: curated_data/curated_data/2COVID/P025_145.png
#   inflating: curated_data/curated_data/2COVID/P025_146.png
#   inflating: curated_data/curated_data/2COVID/P025_147.png
#   inflating: curated_data/curated_data/2COVID/P025_148.png
#   inflating: curated_data/curated_data/2COVID/P025_15.png
#   inflating: curated_data/curated_data/2COVID/P025_150.png
#   inflating: curated_data/curated_data/2COVID/P025_151.png
#   inflating: curated_data/curated_data/2COVID/P025_152.png
#   inflating: curated_data/curated_data/2COVID/P025_153.png
#   inflating: curated_data/curated_data/2COVID/P025_154.png
#   inflating: curated_data/curated_data/2COVID/P025_155.png
#   inflating: curated_data/curated_data/2COVID/P025_156.png
#   inflating: curated_data/curated_data/2COVID/P025_157.png
#   inflating: curated_data/curated_data/2COVID/P025_158.png
#   inflating: curated_data/curated_data/2COVID/P025_159.png
#   inflating: curated_data/curated_data/2COVID/P025_16.png
#   inflating: curated_data/curated_data/2COVID/P025_17.png
#   inflating: curated_data/curated_data/2COVID/P025_18.png
#   inflating: curated_data/curated_data/2COVID/P025_19.png
#   inflating: curated_data/curated_data/2COVID/P025_20.png
#   inflating: curated_data/curated_data/2COVID/P025_21.png
#   inflating: curated_data/curated_data/2COVID/P025_22.png
#   inflating: curated_data/curated_data/2COVID/P025_23.png
#   inflating: curated_data/curated_data/2COVID/P025_25.png
#   inflating: curated_data/curated_data/2COVID/P025_26.png
#   inflating: curated_data/curated_data/2COVID/P025_27.png
#   inflating: curated_data/curated_data/2COVID/P025_28.png
#   inflating: curated_data/curated_data/2COVID/P025_29.png
#   inflating: curated_data/curated_data/2COVID/P025_3.png
#   inflating: curated_data/curated_data/2COVID/P025_30.png
#   inflating: curated_data/curated_data/2COVID/P025_31.png
#   inflating: curated_data/curated_data/2COVID/P025_32.png
#   inflating: curated_data/curated_data/2COVID/P025_33.png
#   inflating: curated_data/curated_data/2COVID/P025_34.png
#   inflating: curated_data/curated_data/2COVID/P025_36.png
#   inflating: curated_data/curated_data/2COVID/P025_37.png
#   inflating: curated_data/curated_data/2COVID/P025_38.png
#   inflating: curated_data/curated_data/2COVID/P025_39.png
#   inflating: curated_data/curated_data/2COVID/P025_4.png
#   inflating: curated_data/curated_data/2COVID/P025_40.png
#   inflating: curated_data/curated_data/2COVID/P025_41.png
#   inflating: curated_data/curated_data/2COVID/P025_42.png
#   inflating: curated_data/curated_data/2COVID/P025_43.png
#   inflating: curated_data/curated_data/2COVID/P025_44.png
#   inflating: curated_data/curated_data/2COVID/P025_5.png
#   inflating: curated_data/curated_data/2COVID/P025_6.png
#   inflating: curated_data/curated_data/2COVID/P025_7.png
#   inflating: curated_data/curated_data/2COVID/P025_8.png
#   inflating: curated_data/curated_data/2COVID/P025_86.png
#   inflating: curated_data/curated_data/2COVID/P025_87.png
#   inflating: curated_data/curated_data/2COVID/P025_88.png
#   inflating: curated_data/curated_data/2COVID/P025_89.png
#   inflating: curated_data/curated_data/2COVID/P025_9.png
#   inflating: curated_data/curated_data/2COVID/P025_90.png
#   inflating: curated_data/curated_data/2COVID/P025_91.png
#   inflating: curated_data/curated_data/2COVID/P025_92.png
#   inflating: curated_data/curated_data/2COVID/P025_93.png
#   inflating: curated_data/curated_data/2COVID/P025_95.png
#   inflating: curated_data/curated_data/2COVID/P025_96.png
#   inflating: curated_data/curated_data/2COVID/P025_97.png
#   inflating: curated_data/curated_data/2COVID/P025_98.png
#   inflating: curated_data/curated_data/2COVID/P025_99.png
#   inflating: curated_data/curated_data/2COVID/P026_10.png
#   inflating: curated_data/curated_data/2COVID/P026_100.png
#   inflating: curated_data/curated_data/2COVID/P026_101.png
#   inflating: curated_data/curated_data/2COVID/P026_102.png
#   inflating: curated_data/curated_data/2COVID/P026_103.png
#   inflating: curated_data/curated_data/2COVID/P026_104.png
#   inflating: curated_data/curated_data/2COVID/P026_105.png
#   inflating: curated_data/curated_data/2COVID/P026_106.png
#   inflating: curated_data/curated_data/2COVID/P026_107.png
#   inflating: curated_data/curated_data/2COVID/P026_108.png
#   inflating: curated_data/curated_data/2COVID/P026_11.png
#   inflating: curated_data/curated_data/2COVID/P026_110.png
#   inflating: curated_data/curated_data/2COVID/P026_111.png
#   inflating: curated_data/curated_data/2COVID/P026_112.png
#   inflating: curated_data/curated_data/2COVID/P026_113.png
#   inflating: curated_data/curated_data/2COVID/P026_114.png
#   inflating: curated_data/curated_data/2COVID/P026_115.png
#   inflating: curated_data/curated_data/2COVID/P026_116.png
#   inflating: curated_data/curated_data/2COVID/P026_117.png
#   inflating: curated_data/curated_data/2COVID/P026_118.png
#   inflating: curated_data/curated_data/2COVID/P026_119.png
#   inflating: curated_data/curated_data/2COVID/P026_12.png
#   inflating: curated_data/curated_data/2COVID/P026_121.png
#   inflating: curated_data/curated_data/2COVID/P026_122.png
#   inflating: curated_data/curated_data/2COVID/P026_123.png
#   inflating: curated_data/curated_data/2COVID/P026_124.png
#   inflating: curated_data/curated_data/2COVID/P026_125.png
#   inflating: curated_data/curated_data/2COVID/P026_126.png
#   inflating: curated_data/curated_data/2COVID/P026_127.png
#   inflating: curated_data/curated_data/2COVID/P026_128.png
#   inflating: curated_data/curated_data/2COVID/P026_129.png
#   inflating: curated_data/curated_data/2COVID/P026_130.png
#   inflating: curated_data/curated_data/2COVID/P026_132.png
#   inflating: curated_data/curated_data/2COVID/P026_133.png
#   inflating: curated_data/curated_data/2COVID/P026_134.png
#   inflating: curated_data/curated_data/2COVID/P026_135.png
#   inflating: curated_data/curated_data/2COVID/P026_136.png
#   inflating: curated_data/curated_data/2COVID/P026_137.png
#   inflating: curated_data/curated_data/2COVID/P026_138.png
#   inflating: curated_data/curated_data/2COVID/P026_139.png
#   inflating: curated_data/curated_data/2COVID/P026_14.png
#   inflating: curated_data/curated_data/2COVID/P026_140.png
#   inflating: curated_data/curated_data/2COVID/P026_141.png
#   inflating: curated_data/curated_data/2COVID/P026_143.png
#   inflating: curated_data/curated_data/2COVID/P026_144.png
#   inflating: curated_data/curated_data/2COVID/P026_145.png
#   inflating: curated_data/curated_data/2COVID/P026_146.png
#   inflating: curated_data/curated_data/2COVID/P026_147.png
#   inflating: curated_data/curated_data/2COVID/P026_148.png
#   inflating: curated_data/curated_data/2COVID/P026_149.png
#   inflating: curated_data/curated_data/2COVID/P026_15.png
#   inflating: curated_data/curated_data/2COVID/P026_150.png
#   inflating: curated_data/curated_data/2COVID/P026_151.png
#   inflating: curated_data/curated_data/2COVID/P026_152.png
#   inflating: curated_data/curated_data/2COVID/P026_16.png
#   inflating: curated_data/curated_data/2COVID/P026_17.png
#   inflating: curated_data/curated_data/2COVID/P026_18.png
#   inflating: curated_data/curated_data/2COVID/P026_19.png
#   inflating: curated_data/curated_data/2COVID/P026_20.png
#   inflating: curated_data/curated_data/2COVID/P026_21.png
#   inflating: curated_data/curated_data/2COVID/P026_22.png
#   inflating: curated_data/curated_data/2COVID/P026_23.png
#   inflating: curated_data/curated_data/2COVID/P026_25.png
#   inflating: curated_data/curated_data/2COVID/P026_26.png
#   inflating: curated_data/curated_data/2COVID/P026_27.png
#   inflating: curated_data/curated_data/2COVID/P026_28.png
#   inflating: curated_data/curated_data/2COVID/P026_29.png
#   inflating: curated_data/curated_data/2COVID/P026_3.png
#   inflating: curated_data/curated_data/2COVID/P026_30.png
#   inflating: curated_data/curated_data/2COVID/P026_31.png
#   inflating: curated_data/curated_data/2COVID/P026_32.png
#   inflating: curated_data/curated_data/2COVID/P026_33.png
#   inflating: curated_data/curated_data/2COVID/P026_34.png
#   inflating: curated_data/curated_data/2COVID/P026_36.png
#   inflating: curated_data/curated_data/2COVID/P026_4.png
#   inflating: curated_data/curated_data/2COVID/P026_5.png
#   inflating: curated_data/curated_data/2COVID/P026_6.png
#   inflating: curated_data/curated_data/2COVID/P026_7.png
#   inflating: curated_data/curated_data/2COVID/P026_8.png
#   inflating: curated_data/curated_data/2COVID/P026_83.png
#   inflating: curated_data/curated_data/2COVID/P026_84.png
#   inflating: curated_data/curated_data/2COVID/P026_85.png
#   inflating: curated_data/curated_data/2COVID/P026_86.png
#   inflating: curated_data/curated_data/2COVID/P026_88.png
#   inflating: curated_data/curated_data/2COVID/P026_89.png
#   inflating: curated_data/curated_data/2COVID/P026_9.png
#   inflating: curated_data/curated_data/2COVID/P026_90.png
#   inflating: curated_data/curated_data/2COVID/P026_91.png
#   inflating: curated_data/curated_data/2COVID/P026_92.png
#   inflating: curated_data/curated_data/2COVID/P026_93.png
#   inflating: curated_data/curated_data/2COVID/P026_94.png
#   inflating: curated_data/curated_data/2COVID/P026_95.png
#   inflating: curated_data/curated_data/2COVID/P026_96.png
#   inflating: curated_data/curated_data/2COVID/P026_97.png
#   inflating: curated_data/curated_data/2COVID/P026_99.png
#   inflating: curated_data/curated_data/2COVID/P027_100.png
#   inflating: curated_data/curated_data/2COVID/P027_101.png
#   inflating: curated_data/curated_data/2COVID/P027_103.png
#   inflating: curated_data/curated_data/2COVID/P027_104.png
#   inflating: curated_data/curated_data/2COVID/P027_105.png
#   inflating: curated_data/curated_data/2COVID/P027_106.png
#   inflating: curated_data/curated_data/2COVID/P027_107.png
#   inflating: curated_data/curated_data/2COVID/P027_108.png
#   inflating: curated_data/curated_data/2COVID/P027_109.png
#   inflating: curated_data/curated_data/2COVID/P027_110.png
#   inflating: curated_data/curated_data/2COVID/P027_111.png
#   inflating: curated_data/curated_data/2COVID/P027_112.png
#   inflating: curated_data/curated_data/2COVID/P027_114.png
#   inflating: curated_data/curated_data/2COVID/P027_115.png
#   inflating: curated_data/curated_data/2COVID/P027_116.png
#   inflating: curated_data/curated_data/2COVID/P027_117.png
#   inflating: curated_data/curated_data/2COVID/P027_118.png
#   inflating: curated_data/curated_data/2COVID/P027_119.png
#   inflating: curated_data/curated_data/2COVID/P027_51.png
#   inflating: curated_data/curated_data/2COVID/P027_52.png
#   inflating: curated_data/curated_data/2COVID/P027_53.png
#   inflating: curated_data/curated_data/2COVID/P027_54.png
#   inflating: curated_data/curated_data/2COVID/P027_55.png
#   inflating: curated_data/curated_data/2COVID/P027_56.png
#   inflating: curated_data/curated_data/2COVID/P027_57.png
#   inflating: curated_data/curated_data/2COVID/P027_59.png
#   inflating: curated_data/curated_data/2COVID/P027_60.png
#   inflating: curated_data/curated_data/2COVID/P027_61.png
#   inflating: curated_data/curated_data/2COVID/P027_62.png
#   inflating: curated_data/curated_data/2COVID/P027_63.png
#   inflating: curated_data/curated_data/2COVID/P027_64.png
#   inflating: curated_data/curated_data/2COVID/P027_65.png
#   inflating: curated_data/curated_data/2COVID/P027_66.png
#   inflating: curated_data/curated_data/2COVID/P027_67.png
#   inflating: curated_data/curated_data/2COVID/P027_68.png
#   inflating: curated_data/curated_data/2COVID/P027_70.png
#   inflating: curated_data/curated_data/2COVID/P027_71.png
#   inflating: curated_data/curated_data/2COVID/P027_72.png
#   inflating: curated_data/curated_data/2COVID/P027_73.png
#   inflating: curated_data/curated_data/2COVID/P027_74.png
#   inflating: curated_data/curated_data/2COVID/P027_75.png
#   inflating: curated_data/curated_data/2COVID/P027_76.png
#   inflating: curated_data/curated_data/2COVID/P027_77.png
#   inflating: curated_data/curated_data/2COVID/P027_78.png
#   inflating: curated_data/curated_data/2COVID/P027_79.png
#   inflating: curated_data/curated_data/2COVID/P027_81.png
#   inflating: curated_data/curated_data/2COVID/P027_82.png
#   inflating: curated_data/curated_data/2COVID/P027_83.png
#   inflating: curated_data/curated_data/2COVID/P027_84.png
#   inflating: curated_data/curated_data/2COVID/P027_85.png
#   inflating: curated_data/curated_data/2COVID/P027_86.png
#   inflating: curated_data/curated_data/2COVID/P027_87.png
#   inflating: curated_data/curated_data/2COVID/P027_88.png
#   inflating: curated_data/curated_data/2COVID/P027_89.png
#   inflating: curated_data/curated_data/2COVID/P027_90.png
#   inflating: curated_data/curated_data/2COVID/P027_92.png
#   inflating: curated_data/curated_data/2COVID/P027_93.png
#   inflating: curated_data/curated_data/2COVID/P027_94.png
#   inflating: curated_data/curated_data/2COVID/P027_95.png
#   inflating: curated_data/curated_data/2COVID/P027_96.png
#   inflating: curated_data/curated_data/2COVID/P027_97.png
#   inflating: curated_data/curated_data/2COVID/P027_98.png
#   inflating: curated_data/curated_data/2COVID/P027_99.png
#   inflating: curated_data/curated_data/2COVID/P028_10.png
#   inflating: curated_data/curated_data/2COVID/P028_100.png
#   inflating: curated_data/curated_data/2COVID/P028_101.png
#   inflating: curated_data/curated_data/2COVID/P028_102.png
#   inflating: curated_data/curated_data/2COVID/P028_104.png
#   inflating: curated_data/curated_data/2COVID/P028_105.png
#   inflating: curated_data/curated_data/2COVID/P028_11.png
#   inflating: curated_data/curated_data/2COVID/P028_118.png
#   inflating: curated_data/curated_data/2COVID/P028_119.png
#   inflating: curated_data/curated_data/2COVID/P028_12.png
#   inflating: curated_data/curated_data/2COVID/P028_120.png
#   inflating: curated_data/curated_data/2COVID/P028_121.png
#   inflating: curated_data/curated_data/2COVID/P028_122.png
#   inflating: curated_data/curated_data/2COVID/P028_123.png
#   inflating: curated_data/curated_data/2COVID/P028_124.png
#   inflating: curated_data/curated_data/2COVID/P028_126.png
#   inflating: curated_data/curated_data/2COVID/P028_127.png
#   inflating: curated_data/curated_data/2COVID/P028_128.png
#   inflating: curated_data/curated_data/2COVID/P028_129.png
#   inflating: curated_data/curated_data/2COVID/P028_130.png
#   inflating: curated_data/curated_data/2COVID/P028_131.png
#   inflating: curated_data/curated_data/2COVID/P028_132.png
#   inflating: curated_data/curated_data/2COVID/P028_133.png
#   inflating: curated_data/curated_data/2COVID/P028_134.png
#   inflating: curated_data/curated_data/2COVID/P028_135.png
#   inflating: curated_data/curated_data/2COVID/P028_14.png
#   inflating: curated_data/curated_data/2COVID/P028_15.png
#   inflating: curated_data/curated_data/2COVID/P028_16.png
#   inflating: curated_data/curated_data/2COVID/P028_3.png
#   inflating: curated_data/curated_data/2COVID/P028_4.png
#   inflating: curated_data/curated_data/2COVID/P028_47.png
#   inflating: curated_data/curated_data/2COVID/P028_49.png
#   inflating: curated_data/curated_data/2COVID/P028_5.png
#   inflating: curated_data/curated_data/2COVID/P028_50.png
#   inflating: curated_data/curated_data/2COVID/P028_51.png
#   inflating: curated_data/curated_data/2COVID/P028_52.png
#   inflating: curated_data/curated_data/2COVID/P028_53.png
#   inflating: curated_data/curated_data/2COVID/P028_54.png
#   inflating: curated_data/curated_data/2COVID/P028_55.png
#   inflating: curated_data/curated_data/2COVID/P028_56.png
#   inflating: curated_data/curated_data/2COVID/P028_57.png
#   inflating: curated_data/curated_data/2COVID/P028_58.png
#   inflating: curated_data/curated_data/2COVID/P028_6.png
#   inflating: curated_data/curated_data/2COVID/P028_60.png
#   inflating: curated_data/curated_data/2COVID/P028_61.png
#   inflating: curated_data/curated_data/2COVID/P028_62.png
#   inflating: curated_data/curated_data/2COVID/P028_63.png
#   inflating: curated_data/curated_data/2COVID/P028_64.png
#   inflating: curated_data/curated_data/2COVID/P028_65.png
#   inflating: curated_data/curated_data/2COVID/P028_66.png
#   inflating: curated_data/curated_data/2COVID/P028_67.png
#   inflating: curated_data/curated_data/2COVID/P028_68.png
#   inflating: curated_data/curated_data/2COVID/P028_69.png
#   inflating: curated_data/curated_data/2COVID/P028_7.png
#   inflating: curated_data/curated_data/2COVID/P028_71.png
#   inflating: curated_data/curated_data/2COVID/P028_72.png
#   inflating: curated_data/curated_data/2COVID/P028_73.png
#   inflating: curated_data/curated_data/2COVID/P028_74.png
#   inflating: curated_data/curated_data/2COVID/P028_75.png
#   inflating: curated_data/curated_data/2COVID/P028_76.png
#   inflating: curated_data/curated_data/2COVID/P028_77.png
#   inflating: curated_data/curated_data/2COVID/P028_78.png
#   inflating: curated_data/curated_data/2COVID/P028_79.png
#   inflating: curated_data/curated_data/2COVID/P028_8.png
#   inflating: curated_data/curated_data/2COVID/P028_80.png
#   inflating: curated_data/curated_data/2COVID/P028_82.png
#   inflating: curated_data/curated_data/2COVID/P028_83.png
#   inflating: curated_data/curated_data/2COVID/P028_84.png
#   inflating: curated_data/curated_data/2COVID/P028_85.png
#   inflating: curated_data/curated_data/2COVID/P028_86.png
#   inflating: curated_data/curated_data/2COVID/P028_87.png
#   inflating: curated_data/curated_data/2COVID/P028_88.png
#   inflating: curated_data/curated_data/2COVID/P028_89.png
#   inflating: curated_data/curated_data/2COVID/P028_9.png
#   inflating: curated_data/curated_data/2COVID/P028_90.png
#   inflating: curated_data/curated_data/2COVID/P028_94.png
#   inflating: curated_data/curated_data/2COVID/P028_95.png
#   inflating: curated_data/curated_data/2COVID/P028_96.png
#   inflating: curated_data/curated_data/2COVID/P028_97.png
#   inflating: curated_data/curated_data/2COVID/P028_98.png
#   inflating: curated_data/curated_data/2COVID/P028_99.png
#   inflating: curated_data/curated_data/2COVID/P029_10.png
#   inflating: curated_data/curated_data/2COVID/P029_100.png
#   inflating: curated_data/curated_data/2COVID/P029_101.png
#   inflating: curated_data/curated_data/2COVID/P029_102.png
#   inflating: curated_data/curated_data/2COVID/P029_103.png
#   inflating: curated_data/curated_data/2COVID/P029_104.png
#   inflating: curated_data/curated_data/2COVID/P029_105.png
#   inflating: curated_data/curated_data/2COVID/P029_106.png
#   inflating: curated_data/curated_data/2COVID/P029_107.png
#   inflating: curated_data/curated_data/2COVID/P029_108.png
#   inflating: curated_data/curated_data/2COVID/P029_109.png
#   inflating: curated_data/curated_data/2COVID/P029_11.png
#   inflating: curated_data/curated_data/2COVID/P029_111.png
#   inflating: curated_data/curated_data/2COVID/P029_112.png
#   inflating: curated_data/curated_data/2COVID/P029_113.png
#   inflating: curated_data/curated_data/2COVID/P029_114.png
#   inflating: curated_data/curated_data/2COVID/P029_115.png
#   inflating: curated_data/curated_data/2COVID/P029_116.png
#   inflating: curated_data/curated_data/2COVID/P029_117.png
#   inflating: curated_data/curated_data/2COVID/P029_118.png
#   inflating: curated_data/curated_data/2COVID/P029_119.png
#   inflating: curated_data/curated_data/2COVID/P029_12.png
#   inflating: curated_data/curated_data/2COVID/P029_120.png
#   inflating: curated_data/curated_data/2COVID/P029_122.png
#   inflating: curated_data/curated_data/2COVID/P029_123.png
#   inflating: curated_data/curated_data/2COVID/P029_124.png
#   inflating: curated_data/curated_data/2COVID/P029_125.png
#   inflating: curated_data/curated_data/2COVID/P029_126.png
#   inflating: curated_data/curated_data/2COVID/P029_127.png
#   inflating: curated_data/curated_data/2COVID/P029_128.png
#   inflating: curated_data/curated_data/2COVID/P029_129.png
#   inflating: curated_data/curated_data/2COVID/P029_13.png
#   inflating: curated_data/curated_data/2COVID/P029_130.png
#   inflating: curated_data/curated_data/2COVID/P029_131.png
#   inflating: curated_data/curated_data/2COVID/P029_14.png
#   inflating: curated_data/curated_data/2COVID/P029_15.png
#   inflating: curated_data/curated_data/2COVID/P029_16.png
#   inflating: curated_data/curated_data/2COVID/P029_17.png
#   inflating: curated_data/curated_data/2COVID/P029_18.png
#   inflating: curated_data/curated_data/2COVID/P029_19.png
#   inflating: curated_data/curated_data/2COVID/P029_20.png
#   inflating: curated_data/curated_data/2COVID/P029_21.png
#   inflating: curated_data/curated_data/2COVID/P029_22.png
#   inflating: curated_data/curated_data/2COVID/P029_23.png
#   inflating: curated_data/curated_data/2COVID/P029_24.png
#   inflating: curated_data/curated_data/2COVID/P029_25.png
#   inflating: curated_data/curated_data/2COVID/P029_3.png
#   inflating: curated_data/curated_data/2COVID/P029_35.png
#   inflating: curated_data/curated_data/2COVID/P029_38.png
#   inflating: curated_data/curated_data/2COVID/P029_39.png
#   inflating: curated_data/curated_data/2COVID/P029_4.png
#   inflating: curated_data/curated_data/2COVID/P029_40.png
#   inflating: curated_data/curated_data/2COVID/P029_41.png
#   inflating: curated_data/curated_data/2COVID/P029_42.png
#   inflating: curated_data/curated_data/2COVID/P029_43.png
#   inflating: curated_data/curated_data/2COVID/P029_45.png
#   inflating: curated_data/curated_data/2COVID/P029_46.png
#   inflating: curated_data/curated_data/2COVID/P029_47.png
#   inflating: curated_data/curated_data/2COVID/P029_48.png
#   inflating: curated_data/curated_data/2COVID/P029_49.png
#   inflating: curated_data/curated_data/2COVID/P029_5.png
#   inflating: curated_data/curated_data/2COVID/P029_50.png
#   inflating: curated_data/curated_data/2COVID/P029_51.png
#   inflating: curated_data/curated_data/2COVID/P029_52.png
#   inflating: curated_data/curated_data/2COVID/P029_53.png
#   inflating: curated_data/curated_data/2COVID/P029_54.png
#   inflating: curated_data/curated_data/2COVID/P029_56.png
#   inflating: curated_data/curated_data/2COVID/P029_57.png
#   inflating: curated_data/curated_data/2COVID/P029_58.png
#   inflating: curated_data/curated_data/2COVID/P029_59.png
#   inflating: curated_data/curated_data/2COVID/P029_6.png
#   inflating: curated_data/curated_data/2COVID/P029_60.png
#   inflating: curated_data/curated_data/2COVID/P029_61.png
#   inflating: curated_data/curated_data/2COVID/P029_62.png
#   inflating: curated_data/curated_data/2COVID/P029_63.png
#   inflating: curated_data/curated_data/2COVID/P029_64.png
#   inflating: curated_data/curated_data/2COVID/P029_65.png
#   inflating: curated_data/curated_data/2COVID/P029_67.png
#   inflating: curated_data/curated_data/2COVID/P029_68.png
#   inflating: curated_data/curated_data/2COVID/P029_69.png
#   inflating: curated_data/curated_data/2COVID/P029_7.png
#   inflating: curated_data/curated_data/2COVID/P029_70.png
#   inflating: curated_data/curated_data/2COVID/P029_71.png
#   inflating: curated_data/curated_data/2COVID/P029_72.png
#   inflating: curated_data/curated_data/2COVID/P029_73.png
#   inflating: curated_data/curated_data/2COVID/P029_74.png
#   inflating: curated_data/curated_data/2COVID/P029_75.png
#   inflating: curated_data/curated_data/2COVID/P029_76.png
#   inflating: curated_data/curated_data/2COVID/P029_78.png
#   inflating: curated_data/curated_data/2COVID/P029_79.png
#   inflating: curated_data/curated_data/2COVID/P029_8.png
#   inflating: curated_data/curated_data/2COVID/P029_80.png
#   inflating: curated_data/curated_data/2COVID/P029_81.png
#   inflating: curated_data/curated_data/2COVID/P029_82.png
#   inflating: curated_data/curated_data/2COVID/P029_83.png
#   inflating: curated_data/curated_data/2COVID/P029_84.png
#   inflating: curated_data/curated_data/2COVID/P029_85.png
#   inflating: curated_data/curated_data/2COVID/P029_86.png
#   inflating: curated_data/curated_data/2COVID/P029_87.png
#   inflating: curated_data/curated_data/2COVID/P029_89.png
#   inflating: curated_data/curated_data/2COVID/P029_9.png
#   inflating: curated_data/curated_data/2COVID/P029_90.png
#   inflating: curated_data/curated_data/2COVID/P029_91.png
#   inflating: curated_data/curated_data/2COVID/P029_92.png
#   inflating: curated_data/curated_data/2COVID/P029_93.png
#   inflating: curated_data/curated_data/2COVID/P029_94.png
#   inflating: curated_data/curated_data/2COVID/P029_95.png
#   inflating: curated_data/curated_data/2COVID/P029_96.png
#   inflating: curated_data/curated_data/2COVID/P029_97.png
#   inflating: curated_data/curated_data/2COVID/P029_98.png
#   inflating: curated_data/curated_data/2COVID/P030_10.png
#   inflating: curated_data/curated_data/2COVID/P030_100.png
#   inflating: curated_data/curated_data/2COVID/P030_101.png
#   inflating: curated_data/curated_data/2COVID/P030_102.png
#   inflating: curated_data/curated_data/2COVID/P030_103.png
#   inflating: curated_data/curated_data/2COVID/P030_104.png
#   inflating: curated_data/curated_data/2COVID/P030_105.png
#   inflating: curated_data/curated_data/2COVID/P030_106.png
#   inflating: curated_data/curated_data/2COVID/P030_107.png
#   inflating: curated_data/curated_data/2COVID/P030_108.png
#   inflating: curated_data/curated_data/2COVID/P030_109.png
#   inflating: curated_data/curated_data/2COVID/P030_11.png
#   inflating: curated_data/curated_data/2COVID/P030_111.png
#   inflating: curated_data/curated_data/2COVID/P030_112.png
#   inflating: curated_data/curated_data/2COVID/P030_113.png
#   inflating: curated_data/curated_data/2COVID/P030_114.png
#   inflating: curated_data/curated_data/2COVID/P030_115.png
#   inflating: curated_data/curated_data/2COVID/P030_116.png
#   inflating: curated_data/curated_data/2COVID/P030_117.png
#   inflating: curated_data/curated_data/2COVID/P030_118.png
#   inflating: curated_data/curated_data/2COVID/P030_119.png
#   inflating: curated_data/curated_data/2COVID/P030_12.png
#   inflating: curated_data/curated_data/2COVID/P030_120.png
#   inflating: curated_data/curated_data/2COVID/P030_122.png
#   inflating: curated_data/curated_data/2COVID/P030_123.png
#   inflating: curated_data/curated_data/2COVID/P030_124.png
#   inflating: curated_data/curated_data/2COVID/P030_125.png
#   inflating: curated_data/curated_data/2COVID/P030_126.png
#   inflating: curated_data/curated_data/2COVID/P030_127.png
#   inflating: curated_data/curated_data/2COVID/P030_128.png
#   inflating: curated_data/curated_data/2COVID/P030_129.png
#   inflating: curated_data/curated_data/2COVID/P030_130.png
#   inflating: curated_data/curated_data/2COVID/P030_131.png
#   inflating: curated_data/curated_data/2COVID/P030_136.png
#   inflating: curated_data/curated_data/2COVID/P030_137.png
#   inflating: curated_data/curated_data/2COVID/P030_138.png
#   inflating: curated_data/curated_data/2COVID/P030_139.png
#   inflating: curated_data/curated_data/2COVID/P030_14.png
#   inflating: curated_data/curated_data/2COVID/P030_140.png
#   inflating: curated_data/curated_data/2COVID/P030_141.png
#   inflating: curated_data/curated_data/2COVID/P030_142.png
#   inflating: curated_data/curated_data/2COVID/P030_3.png
#   inflating: curated_data/curated_data/2COVID/P030_4.png
#   inflating: curated_data/curated_data/2COVID/P030_5.png
#   inflating: curated_data/curated_data/2COVID/P030_6.png
#   inflating: curated_data/curated_data/2COVID/P030_61.png
#   inflating: curated_data/curated_data/2COVID/P030_62.png
#   inflating: curated_data/curated_data/2COVID/P030_63.png
#   inflating: curated_data/curated_data/2COVID/P030_64.png
#   inflating: curated_data/curated_data/2COVID/P030_65.png
#   inflating: curated_data/curated_data/2COVID/P030_67.png
#   inflating: curated_data/curated_data/2COVID/P030_68.png
#   inflating: curated_data/curated_data/2COVID/P030_69.png
#   inflating: curated_data/curated_data/2COVID/P030_7.png
#   inflating: curated_data/curated_data/2COVID/P030_70.png
#   inflating: curated_data/curated_data/2COVID/P030_71.png
#   inflating: curated_data/curated_data/2COVID/P030_72.png
#   inflating: curated_data/curated_data/2COVID/P030_73.png
#   inflating: curated_data/curated_data/2COVID/P030_74.png
#   inflating: curated_data/curated_data/2COVID/P030_75.png
#   inflating: curated_data/curated_data/2COVID/P030_76.png
#   inflating: curated_data/curated_data/2COVID/P030_78.png
#   inflating: curated_data/curated_data/2COVID/P030_79.png
#   inflating: curated_data/curated_data/2COVID/P030_8.png
#   inflating: curated_data/curated_data/2COVID/P030_80.png
#   inflating: curated_data/curated_data/2COVID/P030_81.png
#   inflating: curated_data/curated_data/2COVID/P030_82.png
#   inflating: curated_data/curated_data/2COVID/P030_83.png
#   inflating: curated_data/curated_data/2COVID/P030_84.png
#   inflating: curated_data/curated_data/2COVID/P030_9.png
#   inflating: curated_data/curated_data/2COVID/P030_92.png
#   inflating: curated_data/curated_data/2COVID/P030_93.png
#   inflating: curated_data/curated_data/2COVID/P030_94.png
#   inflating: curated_data/curated_data/2COVID/P030_95.png
#   inflating: curated_data/curated_data/2COVID/P030_96.png
#   inflating: curated_data/curated_data/2COVID/P030_97.png
#   inflating: curated_data/curated_data/2COVID/P030_98.png
#   inflating: curated_data/curated_data/2COVID/P031_100.png
#   inflating: curated_data/curated_data/2COVID/P031_101.png
#   inflating: curated_data/curated_data/2COVID/P031_102.png
#   inflating: curated_data/curated_data/2COVID/P031_103.png
#   inflating: curated_data/curated_data/2COVID/P031_63.png
#   inflating: curated_data/curated_data/2COVID/P031_64.png
#   inflating: curated_data/curated_data/2COVID/P031_65.png
#   inflating: curated_data/curated_data/2COVID/P031_67.png
#   inflating: curated_data/curated_data/2COVID/P031_68.png
#   inflating: curated_data/curated_data/2COVID/P031_69.png
#   inflating: curated_data/curated_data/2COVID/P031_70.png
#   inflating: curated_data/curated_data/2COVID/P031_71.png
#   inflating: curated_data/curated_data/2COVID/P031_72.png
#   inflating: curated_data/curated_data/2COVID/P031_73.png
#   inflating: curated_data/curated_data/2COVID/P031_74.png
#   inflating: curated_data/curated_data/2COVID/P031_78.png
#   inflating: curated_data/curated_data/2COVID/P031_79.png
#   inflating: curated_data/curated_data/2COVID/P031_80.png
#   inflating: curated_data/curated_data/2COVID/P031_81.png
#   inflating: curated_data/curated_data/2COVID/P031_82.png
#   inflating: curated_data/curated_data/2COVID/P031_83.png
#   inflating: curated_data/curated_data/2COVID/P031_84.png
#   inflating: curated_data/curated_data/2COVID/P031_85.png
#   inflating: curated_data/curated_data/2COVID/P031_86.png
#   inflating: curated_data/curated_data/2COVID/P031_87.png
#   inflating: curated_data/curated_data/2COVID/P031_89.png
#   inflating: curated_data/curated_data/2COVID/P031_90.png
#   inflating: curated_data/curated_data/2COVID/P031_91.png
#   inflating: curated_data/curated_data/2COVID/P031_92.png
#   inflating: curated_data/curated_data/2COVID/P031_93.png
#   inflating: curated_data/curated_data/2COVID/P031_94.png
#   inflating: curated_data/curated_data/2COVID/P031_95.png
#   inflating: curated_data/curated_data/2COVID/P031_96.png
#   inflating: curated_data/curated_data/2COVID/P031_97.png
#   inflating: curated_data/curated_data/2COVID/P031_98.png
#   inflating: curated_data/curated_data/2COVID/P032_102.png
#   inflating: curated_data/curated_data/2COVID/P032_103.png
#   inflating: curated_data/curated_data/2COVID/P032_105.png
#   inflating: curated_data/curated_data/2COVID/P032_106.png
#   inflating: curated_data/curated_data/2COVID/P032_107.png
#   inflating: curated_data/curated_data/2COVID/P032_118.png
#   inflating: curated_data/curated_data/2COVID/P032_119.png
#   inflating: curated_data/curated_data/2COVID/P032_131.png
#   inflating: curated_data/curated_data/2COVID/P032_3.png
#   inflating: curated_data/curated_data/2COVID/P032_5.png
#   inflating: curated_data/curated_data/2COVID/P032_6.png
#   inflating: curated_data/curated_data/2COVID/P032_8.png
#   inflating: curated_data/curated_data/2COVID/P032_9.png
#   inflating: curated_data/curated_data/2COVID/P033_100.png
#   inflating: curated_data/curated_data/2COVID/P033_101.png
#   inflating: curated_data/curated_data/2COVID/P033_102.png
#   inflating: curated_data/curated_data/2COVID/P033_103.png
#   inflating: curated_data/curated_data/2COVID/P033_104.png
#   inflating: curated_data/curated_data/2COVID/P033_105.png
#   inflating: curated_data/curated_data/2COVID/P033_107.png
#   inflating: curated_data/curated_data/2COVID/P033_108.png
#   inflating: curated_data/curated_data/2COVID/P033_109.png
#   inflating: curated_data/curated_data/2COVID/P033_110.png
#   inflating: curated_data/curated_data/2COVID/P033_111.png
#   inflating: curated_data/curated_data/2COVID/P033_112.png
#   inflating: curated_data/curated_data/2COVID/P033_113.png
#   inflating: curated_data/curated_data/2COVID/P033_114.png
#   inflating: curated_data/curated_data/2COVID/P033_115.png
#   inflating: curated_data/curated_data/2COVID/P033_116.png
#   inflating: curated_data/curated_data/2COVID/P033_118.png
#   inflating: curated_data/curated_data/2COVID/P033_119.png
#   inflating: curated_data/curated_data/2COVID/P033_120.png
#   inflating: curated_data/curated_data/2COVID/P033_121.png
#   inflating: curated_data/curated_data/2COVID/P033_122.png
#   inflating: curated_data/curated_data/2COVID/P033_123.png
#   inflating: curated_data/curated_data/2COVID/P033_124.png
#   inflating: curated_data/curated_data/2COVID/P033_125.png
#   inflating: curated_data/curated_data/2COVID/P033_126.png
#   inflating: curated_data/curated_data/2COVID/P033_127.png
#   inflating: curated_data/curated_data/2COVID/P033_129.png
#   inflating: curated_data/curated_data/2COVID/P033_130.png
#   inflating: curated_data/curated_data/2COVID/P033_131.png
#   inflating: curated_data/curated_data/2COVID/P033_132.png
#   inflating: curated_data/curated_data/2COVID/P033_133.png
#   inflating: curated_data/curated_data/2COVID/P033_134.png
#   inflating: curated_data/curated_data/2COVID/P033_135.png
#   inflating: curated_data/curated_data/2COVID/P033_136.png
#   inflating: curated_data/curated_data/2COVID/P033_137.png
#   inflating: curated_data/curated_data/2COVID/P033_138.png
#   inflating: curated_data/curated_data/2COVID/P033_140.png
#   inflating: curated_data/curated_data/2COVID/P033_141.png
#   inflating: curated_data/curated_data/2COVID/P033_142.png
#   inflating: curated_data/curated_data/2COVID/P033_143.png
#   inflating: curated_data/curated_data/2COVID/P033_144.png
#   inflating: curated_data/curated_data/2COVID/P033_145.png
#   inflating: curated_data/curated_data/2COVID/P033_146.png
#   inflating: curated_data/curated_data/2COVID/P033_147.png
#   inflating: curated_data/curated_data/2COVID/P033_148.png
#   inflating: curated_data/curated_data/2COVID/P033_149.png
#   inflating: curated_data/curated_data/2COVID/P033_21.png
#   inflating: curated_data/curated_data/2COVID/P033_22.png
#   inflating: curated_data/curated_data/2COVID/P033_23.png
#   inflating: curated_data/curated_data/2COVID/P033_25.png
#   inflating: curated_data/curated_data/2COVID/P033_3.png
#   inflating: curated_data/curated_data/2COVID/P033_4.png
#   inflating: curated_data/curated_data/2COVID/P033_5.png
#   inflating: curated_data/curated_data/2COVID/P033_6.png
#   inflating: curated_data/curated_data/2COVID/P033_61.png
#   inflating: curated_data/curated_data/2COVID/P033_63.png
#   inflating: curated_data/curated_data/2COVID/P033_64.png
#   inflating: curated_data/curated_data/2COVID/P033_65.png
#   inflating: curated_data/curated_data/2COVID/P033_66.png
#   inflating: curated_data/curated_data/2COVID/P033_67.png
#   inflating: curated_data/curated_data/2COVID/P033_68.png
#   inflating: curated_data/curated_data/2COVID/P033_69.png
#   inflating: curated_data/curated_data/2COVID/P033_7.png
#   inflating: curated_data/curated_data/2COVID/P033_70.png
#   inflating: curated_data/curated_data/2COVID/P033_71.png
#   inflating: curated_data/curated_data/2COVID/P033_72.png
#   inflating: curated_data/curated_data/2COVID/P033_74.png
#   inflating: curated_data/curated_data/2COVID/P033_77.png
#   inflating: curated_data/curated_data/2COVID/P033_78.png
#   inflating: curated_data/curated_data/2COVID/P033_79.png
#   inflating: curated_data/curated_data/2COVID/P033_8.png
#   inflating: curated_data/curated_data/2COVID/P033_80.png
#   inflating: curated_data/curated_data/2COVID/P033_81.png
#   inflating: curated_data/curated_data/2COVID/P033_82.png
#   inflating: curated_data/curated_data/2COVID/P033_83.png
#   inflating: curated_data/curated_data/2COVID/P033_85.png
#   inflating: curated_data/curated_data/2COVID/P033_86.png
#   inflating: curated_data/curated_data/2COVID/P033_87.png
#   inflating: curated_data/curated_data/2COVID/P033_88.png
#   inflating: curated_data/curated_data/2COVID/P033_89.png
#   inflating: curated_data/curated_data/2COVID/P033_90.png
#   inflating: curated_data/curated_data/2COVID/P033_91.png
#   inflating: curated_data/curated_data/2COVID/P033_92.png
#   inflating: curated_data/curated_data/2COVID/P033_93.png
#   inflating: curated_data/curated_data/2COVID/P033_94.png
#   inflating: curated_data/curated_data/2COVID/P033_96.png
#   inflating: curated_data/curated_data/2COVID/P033_97.png
#   inflating: curated_data/curated_data/2COVID/P033_98.png
#   inflating: curated_data/curated_data/2COVID/P033_99.png
#   inflating: curated_data/curated_data/2COVID/P034_10.png
#   inflating: curated_data/curated_data/2COVID/P034_100.png
#   inflating: curated_data/curated_data/2COVID/P034_101.png
#   inflating: curated_data/curated_data/2COVID/P034_102.png
#   inflating: curated_data/curated_data/2COVID/P034_103.png
#   inflating: curated_data/curated_data/2COVID/P034_104.png
#   inflating: curated_data/curated_data/2COVID/P034_105.png
#   inflating: curated_data/curated_data/2COVID/P034_107.png
#   inflating: curated_data/curated_data/2COVID/P034_108.png
#   inflating: curated_data/curated_data/2COVID/P034_109.png
#   inflating: curated_data/curated_data/2COVID/P034_11.png
#   inflating: curated_data/curated_data/2COVID/P034_110.png
#   inflating: curated_data/curated_data/2COVID/P034_111.png
#   inflating: curated_data/curated_data/2COVID/P034_112.png
#   inflating: curated_data/curated_data/2COVID/P034_113.png
#   inflating: curated_data/curated_data/2COVID/P034_114.png
#   inflating: curated_data/curated_data/2COVID/P034_115.png
#   inflating: curated_data/curated_data/2COVID/P034_116.png
#   inflating: curated_data/curated_data/2COVID/P034_118.png
#   inflating: curated_data/curated_data/2COVID/P034_119.png
#   inflating: curated_data/curated_data/2COVID/P034_12.png
#   inflating: curated_data/curated_data/2COVID/P034_120.png
#   inflating: curated_data/curated_data/2COVID/P034_121.png
#   inflating: curated_data/curated_data/2COVID/P034_122.png
#   inflating: curated_data/curated_data/2COVID/P034_123.png
#   inflating: curated_data/curated_data/2COVID/P034_124.png
#   inflating: curated_data/curated_data/2COVID/P034_125.png
#   inflating: curated_data/curated_data/2COVID/P034_126.png
#   inflating: curated_data/curated_data/2COVID/P034_127.png
#   inflating: curated_data/curated_data/2COVID/P034_129.png
#   inflating: curated_data/curated_data/2COVID/P034_130.png
#   inflating: curated_data/curated_data/2COVID/P034_131.png
#   inflating: curated_data/curated_data/2COVID/P034_132.png
#   inflating: curated_data/curated_data/2COVID/P034_133.png
#   inflating: curated_data/curated_data/2COVID/P034_134.png
#   inflating: curated_data/curated_data/2COVID/P034_135.png
#   inflating: curated_data/curated_data/2COVID/P034_136.png
#   inflating: curated_data/curated_data/2COVID/P034_137.png
#   inflating: curated_data/curated_data/2COVID/P034_138.png
#   inflating: curated_data/curated_data/2COVID/P034_14.png
#   inflating: curated_data/curated_data/2COVID/P034_140.png
#   inflating: curated_data/curated_data/2COVID/P034_141.png
#   inflating: curated_data/curated_data/2COVID/P034_142.png
#   inflating: curated_data/curated_data/2COVID/P034_143.png
#   inflating: curated_data/curated_data/2COVID/P034_144.png
#   inflating: curated_data/curated_data/2COVID/P034_145.png
#   inflating: curated_data/curated_data/2COVID/P034_146.png
#   inflating: curated_data/curated_data/2COVID/P034_147.png
#   inflating: curated_data/curated_data/2COVID/P034_148.png
#   inflating: curated_data/curated_data/2COVID/P034_149.png
#   inflating: curated_data/curated_data/2COVID/P034_15.png
#   inflating: curated_data/curated_data/2COVID/P034_151.png
#   inflating: curated_data/curated_data/2COVID/P034_152.png
#   inflating: curated_data/curated_data/2COVID/P034_153.png
#   inflating: curated_data/curated_data/2COVID/P034_154.png
#   inflating: curated_data/curated_data/2COVID/P034_155.png
#   inflating: curated_data/curated_data/2COVID/P034_156.png
#   inflating: curated_data/curated_data/2COVID/P034_157.png
#   inflating: curated_data/curated_data/2COVID/P034_158.png
#   inflating: curated_data/curated_data/2COVID/P034_159.png
#   inflating: curated_data/curated_data/2COVID/P034_16.png
#   inflating: curated_data/curated_data/2COVID/P034_160.png
#   inflating: curated_data/curated_data/2COVID/P034_17.png
#   inflating: curated_data/curated_data/2COVID/P034_18.png
#   inflating: curated_data/curated_data/2COVID/P034_19.png
#   inflating: curated_data/curated_data/2COVID/P034_20.png
#   inflating: curated_data/curated_data/2COVID/P034_21.png
#   inflating: curated_data/curated_data/2COVID/P034_22.png
# ...
#   inflating: curated_data/curated_data/3CAP/cp021_116.png
#   inflating: curated_data/curated_data/3CAP/cp021_117.png
#   inflating: curated_data/curated_data/3CAP/cp021_118.png
#   inflating: curated_data/curated_data/3CAP/cp021_119.png
#   inflating: curated_data/curated_data/3CAP/cp021_120.png
#   inflating: curated_data/curated_data/3CAP/cp021_121.png
#   inflating: curated_data/curated_data/3CAP/cp021_122.png
#   inflating: curated_data/curated_data/3CAP/cp021_124.png
#   inflating: curated_data/curated_data/3CAP/cp021_125.png
#   inflating: curated_data/curated_data/3CAP/cp021_126.png
#   inflating: curated_data/curated_data/3CAP/cp021_127.png
#   inflating: curated_data/curated_data/3CAP/cp021_128.png
#   inflating: curated_data/curated_data/3CAP/cp021_129.png
#   inflating: curated_data/curated_data/3CAP/cp021_130.png
#   inflating: curated_data/curated_data/3CAP/cp021_131.png
#   inflating: curated_data/curated_data/3CAP/cp021_132.png
#   inflating: curated_data/curated_data/3CAP/cp021_133.png
#   inflating: curated_data/curated_data/3CAP/cp021_3.png
#   inflating: curated_data/curated_data/3CAP/cp021_4.png
#   inflating: curated_data/curated_data/3CAP/cp021_5.png
#   inflating: curated_data/curated_data/3CAP/cp021_6.png
#   inflating: curated_data/curated_data/3CAP/cp021_7.png
#   inflating: curated_data/curated_data/3CAP/cp021_87.png
#   inflating: curated_data/curated_data/3CAP/cp021_88.png
#   inflating: curated_data/curated_data/3CAP/cp021_89.png
#   inflating: curated_data/curated_data/3CAP/cp021_91.png
#   inflating: curated_data/curated_data/3CAP/cp021_92.png
#   inflating: curated_data/curated_data/3CAP/cp021_93.png
#   inflating: curated_data/curated_data/3CAP/cp021_94.png
#   inflating: curated_data/curated_data/3CAP/cp021_95.png
#   inflating: curated_data/curated_data/3CAP/cp021_96.png
#   inflating: curated_data/curated_data/3CAP/cp021_97.png
#   inflating: curated_data/curated_data/3CAP/cp021_98.png
#   inflating: curated_data/curated_data/3CAP/cp021_99.png
#   inflating: curated_data/curated_data/3CAP/cp022_11.png
#   inflating: curated_data/curated_data/3CAP/cp022_12.png
#   inflating: curated_data/curated_data/3CAP/cp022_14.png
#   inflating: curated_data/curated_data/3CAP/cp022_15.png
#   inflating: curated_data/curated_data/3CAP/cp022_16.png
#   inflating: curated_data/curated_data/3CAP/cp022_17.png
#   inflating: curated_data/curated_data/3CAP/cp022_18.png
#   inflating: curated_data/curated_data/3CAP/cp022_19.png
#   inflating: curated_data/curated_data/3CAP/cp022_20.png
#   inflating: curated_data/curated_data/3CAP/cp022_21.png
#   inflating: curated_data/curated_data/3CAP/cp022_22.png
#   inflating: curated_data/curated_data/3CAP/cp022_23.png
#   inflating: curated_data/curated_data/3CAP/cp022_25.png
#   inflating: curated_data/curated_data/3CAP/cp022_26.png
#   inflating: curated_data/curated_data/3CAP/cp022_27.png
#   inflating: curated_data/curated_data/3CAP/cp022_28.png
#   inflating: curated_data/curated_data/3CAP/cp022_29.png
#   inflating: curated_data/curated_data/3CAP/cp022_30.png
#   inflating: curated_data/curated_data/3CAP/cp022_31.png
#   inflating: curated_data/curated_data/3CAP/cp023_135.png
#   inflating: curated_data/curated_data/3CAP/cp023_136.png
#   inflating: curated_data/curated_data/3CAP/cp023_137.png
#   inflating: curated_data/curated_data/3CAP/cp023_138.png
#   inflating: curated_data/curated_data/3CAP/cp023_139.png
#   inflating: curated_data/curated_data/3CAP/cp023_14.png
#   inflating: curated_data/curated_data/3CAP/cp023_140.png
#   inflating: curated_data/curated_data/3CAP/cp023_141.png
#   inflating: curated_data/curated_data/3CAP/cp023_142.png
#   inflating: curated_data/curated_data/3CAP/cp023_144.png
#   inflating: curated_data/curated_data/3CAP/cp023_145.png
#   inflating: curated_data/curated_data/3CAP/cp023_146.png
#   inflating: curated_data/curated_data/3CAP/cp023_147.png
#   inflating: curated_data/curated_data/3CAP/cp023_148.png
#   inflating: curated_data/curated_data/3CAP/cp023_149.png
#   inflating: curated_data/curated_data/3CAP/cp023_15.png
#   inflating: curated_data/curated_data/3CAP/cp023_150.png
#   inflating: curated_data/curated_data/3CAP/cp023_151.png
#   inflating: curated_data/curated_data/3CAP/cp023_152.png
#   inflating: curated_data/curated_data/3CAP/cp023_153.png
#   inflating: curated_data/curated_data/3CAP/cp023_155.png
#   inflating: curated_data/curated_data/3CAP/cp023_156.png
#   inflating: curated_data/curated_data/3CAP/cp023_157.png
#   inflating: curated_data/curated_data/3CAP/cp023_158.png
#   inflating: curated_data/curated_data/3CAP/cp023_159.png
#   inflating: curated_data/curated_data/3CAP/cp023_16.png
#   inflating: curated_data/curated_data/3CAP/cp023_17.png
#   inflating: curated_data/curated_data/3CAP/cp023_18.png
#   inflating: curated_data/curated_data/3CAP/cp023_19.png
#   inflating: curated_data/curated_data/3CAP/cp023_20.png
#   inflating: curated_data/curated_data/3CAP/cp023_21.png
#   inflating: curated_data/curated_data/3CAP/cp023_22.png
#   inflating: curated_data/curated_data/3CAP/cp023_23.png
#   inflating: curated_data/curated_data/3CAP/cp023_25.png
#   inflating: curated_data/curated_data/3CAP/cp023_26.png
#   inflating: curated_data/curated_data/3CAP/cp023_27.png
#   inflating: curated_data/curated_data/3CAP/cp023_28.png
#   inflating: curated_data/curated_data/3CAP/cp023_29.png
#   inflating: curated_data/curated_data/3CAP/cp023_30.png
#   inflating: curated_data/curated_data/3CAP/cp023_31.png
#   inflating: curated_data/curated_data/3CAP/cp023_32.png
#   inflating: curated_data/curated_data/3CAP/cp023_33.png
#   inflating: curated_data/curated_data/3CAP/cp023_34.png
#   inflating: curated_data/curated_data/3CAP/cp023_36.png
#   inflating: curated_data/curated_data/3CAP/cp023_37.png
#   inflating: curated_data/curated_data/3CAP/cp023_38.png
#   inflating: curated_data/curated_data/3CAP/cp023_39.png
#   inflating: curated_data/curated_data/3CAP/cp023_40.png
#   inflating: curated_data/curated_data/3CAP/cp023_41.png
#   inflating: curated_data/curated_data/3CAP/cp023_42.png
#   inflating: curated_data/curated_data/3CAP/cp023_43.png
#   inflating: curated_data/curated_data/3CAP/cp023_44.png
#   inflating: curated_data/curated_data/3CAP/cp023_45.png
#   inflating: curated_data/curated_data/3CAP/cp023_47.png
#   inflating: curated_data/curated_data/3CAP/cp023_48.png
#   inflating: curated_data/curated_data/3CAP/cp023_49.png
#   inflating: curated_data/curated_data/3CAP/cp023_50.png
#   inflating: curated_data/curated_data/3CAP/cp023_51.png
#   inflating: curated_data/curated_data/3CAP/cp023_52.png
#   inflating: curated_data/curated_data/3CAP/cp023_53.png
#   inflating: curated_data/curated_data/3CAP/cp023_54.png
#   inflating: curated_data/curated_data/3CAP/cp024_42.png
#   inflating: curated_data/curated_data/3CAP/cp024_43.png
#   inflating: curated_data/curated_data/3CAP/cp024_44.png
#   inflating: curated_data/curated_data/3CAP/cp024_45.png
#   inflating: curated_data/curated_data/3CAP/cp024_47.png
#   inflating: curated_data/curated_data/3CAP/cp024_48.png
#   inflating: curated_data/curated_data/3CAP/cp024_49.png
#   inflating: curated_data/curated_data/3CAP/cp024_50.png
#   inflating: curated_data/curated_data/3CAP/cp024_51.png
#   inflating: curated_data/curated_data/3CAP/cp024_52.png
#   inflating: curated_data/curated_data/3CAP/cp024_53.png
#   inflating: curated_data/curated_data/3CAP/cp024_54.png
#   inflating: curated_data/curated_data/3CAP/cp024_55.png
#   inflating: curated_data/curated_data/3CAP/cp024_56.png
#   inflating: curated_data/curated_data/3CAP/cp024_58.png
#   inflating: curated_data/curated_data/3CAP/cp024_59.png
#   inflating: curated_data/curated_data/3CAP/cp024_60.png
#   inflating: curated_data/curated_data/3CAP/cp024_61.png
#   inflating: curated_data/curated_data/3CAP/cp024_62.png
#   inflating: curated_data/curated_data/3CAP/cp024_63.png
#   inflating: curated_data/curated_data/3CAP/cp024_64.png
#   inflating: curated_data/curated_data/3CAP/cp024_65.png
#   inflating: curated_data/curated_data/3CAP/cp024_66.png
#   inflating: curated_data/curated_data/3CAP/cp024_67.png
#   inflating: curated_data/curated_data/3CAP/cp024_69.png
#   inflating: curated_data/curated_data/3CAP/cp025_10.png
#   inflating: curated_data/curated_data/3CAP/cp025_11.png
#   inflating: curated_data/curated_data/3CAP/cp025_12.png
#   inflating: curated_data/curated_data/3CAP/cp025_134.png
#   inflating: curated_data/curated_data/3CAP/cp025_135.png
#   inflating: curated_data/curated_data/3CAP/cp025_136.png
#   inflating: curated_data/curated_data/3CAP/cp025_137.png
#   inflating: curated_data/curated_data/3CAP/cp025_138.png
#   inflating: curated_data/curated_data/3CAP/cp025_139.png
#   inflating: curated_data/curated_data/3CAP/cp025_14.png
#   inflating: curated_data/curated_data/3CAP/cp025_140.png
#   inflating: curated_data/curated_data/3CAP/cp025_142.png
#   inflating: curated_data/curated_data/3CAP/cp025_143.png
#   inflating: curated_data/curated_data/3CAP/cp025_144.png
#   inflating: curated_data/curated_data/3CAP/cp025_145.png
#   inflating: curated_data/curated_data/3CAP/cp025_146.png
#   inflating: curated_data/curated_data/3CAP/cp025_147.png
#   inflating: curated_data/curated_data/3CAP/cp025_148.png
#   inflating: curated_data/curated_data/3CAP/cp025_149.png
#   inflating: curated_data/curated_data/3CAP/cp025_150.png
#   inflating: curated_data/curated_data/3CAP/cp025_151.png
#   inflating: curated_data/curated_data/3CAP/cp025_3.png
#   inflating: curated_data/curated_data/3CAP/cp025_4.png
#   inflating: curated_data/curated_data/3CAP/cp025_5.png
#   inflating: curated_data/curated_data/3CAP/cp025_6.png
#   inflating: curated_data/curated_data/3CAP/cp025_7.png
#   inflating: curated_data/curated_data/3CAP/cp025_8.png
#   inflating: curated_data/curated_data/3CAP/cp025_9.png
#   inflating: curated_data/curated_data/3CAP/cp026_10.png
#   inflating: curated_data/curated_data/3CAP/cp026_101.png
#   inflating: curated_data/curated_data/3CAP/cp026_102.png
#   inflating: curated_data/curated_data/3CAP/cp026_103.png
#   inflating: curated_data/curated_data/3CAP/cp026_104.png
#   inflating: curated_data/curated_data/3CAP/cp026_105.png
#   inflating: curated_data/curated_data/3CAP/cp026_106.png
#   inflating: curated_data/curated_data/3CAP/cp026_107.png
#   inflating: curated_data/curated_data/3CAP/cp026_108.png
#   inflating: curated_data/curated_data/3CAP/cp026_109.png
#   inflating: curated_data/curated_data/3CAP/cp026_11.png
#   inflating: curated_data/curated_data/3CAP/cp026_110.png
#   inflating: curated_data/curated_data/3CAP/cp026_112.png
#   inflating: curated_data/curated_data/3CAP/cp026_113.png
#   inflating: curated_data/curated_data/3CAP/cp026_114.png
#   inflating: curated_data/curated_data/3CAP/cp026_115.png
#   inflating: curated_data/curated_data/3CAP/cp026_116.png
#   inflating: curated_data/curated_data/3CAP/cp026_117.png
#   inflating: curated_data/curated_data/3CAP/cp026_118.png
#   inflating: curated_data/curated_data/3CAP/cp026_119.png
#   inflating: curated_data/curated_data/3CAP/cp026_12.png
#   inflating: curated_data/curated_data/3CAP/cp026_120.png
#   inflating: curated_data/curated_data/3CAP/cp026_121.png
#   inflating: curated_data/curated_data/3CAP/cp026_123.png
#   inflating: curated_data/curated_data/3CAP/cp026_124.png
#   inflating: curated_data/curated_data/3CAP/cp026_125.png
#   inflating: curated_data/curated_data/3CAP/cp026_126.png
#   inflating: curated_data/curated_data/3CAP/cp026_127.png
#   inflating: curated_data/curated_data/3CAP/cp026_128.png
#   inflating: curated_data/curated_data/3CAP/cp026_129.png
#   inflating: curated_data/curated_data/3CAP/cp026_130.png
#   inflating: curated_data/curated_data/3CAP/cp026_131.png
#   inflating: curated_data/curated_data/3CAP/cp026_132.png
#   inflating: curated_data/curated_data/3CAP/cp026_134.png
#   inflating: curated_data/curated_data/3CAP/cp026_135.png
#   inflating: curated_data/curated_data/3CAP/cp026_136.png
#   inflating: curated_data/curated_data/3CAP/cp026_137.png
#   inflating: curated_data/curated_data/3CAP/cp026_138.png
#   inflating: curated_data/curated_data/3CAP/cp026_139.png
#   inflating: curated_data/curated_data/3CAP/cp026_14.png
#   inflating: curated_data/curated_data/3CAP/cp026_140.png
#   inflating: curated_data/curated_data/3CAP/cp026_141.png
#   inflating: curated_data/curated_data/3CAP/cp026_142.png
#   inflating: curated_data/curated_data/3CAP/cp026_143.png
#   inflating: curated_data/curated_data/3CAP/cp026_145.png
#   inflating: curated_data/curated_data/3CAP/cp026_146.png
#   inflating: curated_data/curated_data/3CAP/cp026_147.png
#   inflating: curated_data/curated_data/3CAP/cp026_148.png
#   inflating: curated_data/curated_data/3CAP/cp026_149.png
#   inflating: curated_data/curated_data/3CAP/cp026_15.png
#   inflating: curated_data/curated_data/3CAP/cp026_150.png
#   inflating: curated_data/curated_data/3CAP/cp026_151.png
#   inflating: curated_data/curated_data/3CAP/cp026_152.png
#   inflating: curated_data/curated_data/3CAP/cp026_153.png
#   inflating: curated_data/curated_data/3CAP/cp026_154.png
#   inflating: curated_data/curated_data/3CAP/cp026_156.png
#   inflating: curated_data/curated_data/3CAP/cp026_157.png
#   inflating: curated_data/curated_data/3CAP/cp026_158.png
#   inflating: curated_data/curated_data/3CAP/cp026_159.png
#   inflating: curated_data/curated_data/3CAP/cp026_16.png
#   inflating: curated_data/curated_data/3CAP/cp026_160.png
#   inflating: curated_data/curated_data/3CAP/cp026_161.png
#   inflating: curated_data/curated_data/3CAP/cp026_165.png
#   inflating: curated_data/curated_data/3CAP/cp026_167.png
#   inflating: curated_data/curated_data/3CAP/cp026_168.png
#   inflating: curated_data/curated_data/3CAP/cp026_169.png
#   inflating: curated_data/curated_data/3CAP/cp026_17.png
#   inflating: curated_data/curated_data/3CAP/cp026_170.png
#   inflating: curated_data/curated_data/3CAP/cp026_171.png
#   inflating: curated_data/curated_data/3CAP/cp026_172.png
#   inflating: curated_data/curated_data/3CAP/cp026_173.png
#   inflating: curated_data/curated_data/3CAP/cp026_174.png
#   inflating: curated_data/curated_data/3CAP/cp026_175.png
#   inflating: curated_data/curated_data/3CAP/cp026_176.png
#   inflating: curated_data/curated_data/3CAP/cp026_18.png
#   inflating: curated_data/curated_data/3CAP/cp026_19.png
#   inflating: curated_data/curated_data/3CAP/cp026_3.png
#   inflating: curated_data/curated_data/3CAP/cp026_35.png
#   inflating: curated_data/curated_data/3CAP/cp026_4.png
#   inflating: curated_data/curated_data/3CAP/cp026_46.png
#   inflating: curated_data/curated_data/3CAP/cp026_5.png
#   inflating: curated_data/curated_data/3CAP/cp026_57.png
#   inflating: curated_data/curated_data/3CAP/cp026_6.png
#   inflating: curated_data/curated_data/3CAP/cp026_68.png
#   inflating: curated_data/curated_data/3CAP/cp026_7.png
#   inflating: curated_data/curated_data/3CAP/cp026_79.png
#   inflating: curated_data/curated_data/3CAP/cp026_8.png
#   inflating: curated_data/curated_data/3CAP/cp026_87.png
#   inflating: curated_data/curated_data/3CAP/cp026_88.png
#   inflating: curated_data/curated_data/3CAP/cp026_9.png
#   inflating: curated_data/curated_data/3CAP/cp026_90.png
#   inflating: curated_data/curated_data/3CAP/cp026_91.png
#   inflating: curated_data/curated_data/3CAP/cp026_92.png
#   inflating: curated_data/curated_data/3CAP/cp026_93.png
#   inflating: curated_data/curated_data/3CAP/cp026_94.png
#   inflating: curated_data/curated_data/3CAP/cp026_95.png
#   inflating: curated_data/curated_data/3CAP/cp026_96.png
#   inflating: curated_data/curated_data/3CAP/cp026_97.png
#   inflating: curated_data/curated_data/3CAP/cp026_98.png
#   inflating: curated_data/curated_data/3CAP/cp026_99.png
#   inflating: meta_data_cap.csv
#   inflating: meta_data_covid.csv
#   inflating: meta_data_normal.csv

# %%
##### Inconsistency between file names and file names in meta data #####
## ==> rename files to the names used in meta_data_covid.csv
# !mv "/content/curated_data/curated_data/2COVID/17_Zhao_Recurrence-of-positive-SARS-CoV-2-RNA-in-C_2020_International-Journal-of-Inf-p1-21%0.png" "/content/curated_data/curated_data/2COVID/17_Zhao_Recurrence-of-COVID-19-SARS-CoV-2-RNA-in-C_2020_International-Journal-of-Inf-p1-21%0.png"

# !mv "/content/curated_data/curated_data/2COVID/17_Zhao_Recurrence-of-positive-SARS-CoV-2-RNA-in-C_2020_International-Journal-of-Inf-p1-21%1.png" "/content/curated_data/curated_data/2COVID/17_Zhao_Recurrence-of-COVID-19-SARS-CoV-2-RNA-in-C_2020_International-Journal-of-Inf-p1-21%1.png"

# %%
#17_Zhao_Recurrence-of-COVID-19-SARS-CoV-2-RNA-in-C_2020_International-Journal-of-Inf-p1-21%0

# %%
# Load data as dataframes
df_meta_cap = pd.read_csv('meta_data_cap.csv')
df_meta_covid = pd.read_csv('meta_data_covid.csv', encoding = "ISO-8859-1")
df_meta_normal = pd.read_csv('meta_data_normal.csv')

# %% [markdown]
# # Data analysis

# %% [markdown]
# ### Analysis of df_meta_cap

# %%
# Get some information about df_meta_cap
print(df_meta_cap.info())
display(df_meta_cap.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2618 entries, 0 to 2617
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   index                        2618 non-null   int64
#  1   File name                    2618 non-null   object
#  2   Patient ID                   2618 non-null   object
#  3   Slices_x                     2618 non-null   int64
#  4   Columns                      2618 non-null   int64
#  5   Date of Last Calibration     2618 non-null   int64
#  6   Diagnosis                    2618 non-null   object
#  7   Distance Source to Detector  2618 non-null   int64
#  8   Distance Source to Patient   2618 non-null   int64
#  9   Exposure Time                2618 non-null   int64
#  10  KVP                          2618 non-null   int64
#  11  Age                          2618 non-null   int64
#  12  Gender                       2618 non-null   object
#  13  Rows                         2618 non-null   int64
#  14  Slice Thickness              2618 non-null   int64
#  15  Slices_y                     2618 non-null   int64
#  16  Study Date                   2618 non-null   int64
#  17  XRayTubeCurrent              2618 non-null   int64
#  18  Last Calibration             2618 non-null   object
#  19  mAs                          2618 non-null   float64
#  20  Country                      2618 non-null   object
# dtypes: float64(1), int64(14), object(6)
# memory usage: 429.6+ KB
# None
#    index      File name Patient ID  ...           Last Calibration    mAs  Country
# 0      0  cap006_10.png     cap006  ...  1 days 00:00:00.000000000  152.4     Iran
# 1      1  cap006_11.png     cap006  ...  1 days 00:00:00.000000000  152.4     Iran
# 2      2  cap006_12.png     cap006  ...  1 days 00:00:00.000000000  152.4     Iran
# 3      3  cap006_14.png     cap006  ...  1 days 00:00:00.000000000  152.4     Iran
# 4      4  cap006_15.png     cap006  ...  1 days 00:00:00.000000000  152.4     Iran
#
# [5 rows x 21 columns]

# %%
df_meta_cap.loc[df_meta_cap.duplicated(),:]  # get duplicates
# Out:
# Empty DataFrame
# Columns: [index, File name, Patient ID, Slices_x, Columns, Date of Last Calibration, Diagnosis, Distance Source to Detector, Distance Source to Patient, Exposure Time, KVP, Age, Gender, Rows, Slice Thickness, Slices_y, Study Date, XRayTubeCurrent, Last Calibration, mAs, Country]
# Index: []

# %%
df_meta_cap['Country'].unique()     # unique countries
# Out:
# array(['Iran'], dtype=object)

# %%
df_meta_cap['Patient ID'].nunique() # number of unique patients
# Out:
# 54

# %%
df_meta_cap['Age'].unique()         # unique ages
# Out:
# array([71, 54, 38, 68, 84, 65, 94, 44, 29, 87, 13, 59, 40, 52, 34, 22, 32,
#        25, 80, 46, 70, 21, 51, 30, 26, 76, 56, 62, 77, 75, 39, 83, 48, 73,
#        74, 55, 93, 37, 89, 58, 67, 12])

# %%
# Display age distribution
df_meta_cap.Age.plot(kind='hist')
plt.show()

# %% [markdown]
# ### Analysis of df_meta_covid

# %%
df_meta_covid.loc[df_meta_covid.duplicated(),:]  # get duplicates
# Out:
# Empty DataFrame
# Columns: [index, File name, Patient ID, Gender, Age, Country, Diagnosis, Slice, Case Discussion, Case Number, Columns, Date, Date of Last Calibration, Distance Source to Detector, Distance Source to Patient, Exposure Time, Image Source, Institution, KVP, Last Calibration, Link, Link2, Other diseases, Presentation, RT_PCR_COVID-19, Rows, Severity, Slice Thickness, Slices, Source_detail, Time, XRayTubeCurrent, category, doi, finding, in_icu, intubated, intubation_present, license, mAs, mask_file, needed_supplemental_O2, study_file, survival, went_icu]
# Index: []

# %%
# Get some information about df_meta_covid
print(df_meta_covid.info())
display(df_meta_covid.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7593 entries, 0 to 7592
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   index                        7593 non-null   int64
#  1   File name                    7593 non-null   object
#  2   Patient ID                   7593 non-null   object
#  3   Gender                       7593 non-null   object
#  4   Age                          7593 non-null   object
#  5   Country                      7593 non-null   object
#  6   Diagnosis                    7593 non-null   object
#  7   Slice                        7210 non-null   float64
#  8   Case Discussion              493 non-null    object
#  9   Case Number                  1944 non-null   object
#  10  Columns                      3815 non-null   float64
#  11  Date                         4491 non-null   object
#  12  Date of Last Calibration     3815 non-null   float64
#  13  Distance Source to Detector  3815 non-null   float64
#  14  Distance Source to Patient   3815 non-null   float64
#  15  Exposure Time                3815 non-null   float64
#  16  Image Source                 1944 non-null   object
#  17  Institution                  7110 non-null   object
#  18  KVP                          3815 non-null   float64
#  19  Last Calibration             3815 non-null   object
#  20  Link                         527 non-null    object
#  21  Link2                        493 non-null    object
#  22  Other diseases               19 non-null     object
#  23  Presentation                 537 non-null    object
#  24  RT_PCR_COVID-19              34 non-null     object
#  25  Rows                         3815 non-null   float64
#  26  Severity                     178 non-null    object
#  27  Slice Thickness              3815 non-null   float64
#  28  Slices                       3815 non-null   float64
#  29  Source_detail                1844 non-null   object
#  30  Time                         134 non-null    object
#  31  XRayTubeCurrent              3815 non-null   float64
#  32  category                     785 non-null    object
#  33  doi                          213 non-null    object
#  34  finding                      863 non-null    object
#  35  in_icu                       8 non-null      object
#  36  intubated                    15 non-null     object
#  37  intubation_present           15 non-null     object
#  38  license                      34 non-null     object
#  39  mAs                          3815 non-null   float64
#  40  mask_file                    785 non-null    object
#  41  needed_supplemental_O2       4 non-null      object
#  42  study_file                   785 non-null    object
#  43  survival                     13 non-null     object
#  44  went_icu                     8 non-null      object
# dtypes: float64(12), int64(1), object(32)
# memory usage: 2.6+ MB
# None
#    index                                          File name  ... survival went_icu
# 0      0  6_Rahimzadeh_137covid_patient101_SR_4_IM00006.png  ...      NaN      NaN
# 1      1  6_Rahimzadeh_137covid_patient101_SR_4_IM00008.png  ...      NaN      NaN
# 2      2  6_Rahimzadeh_137covid_patient101_SR_4_IM00009.png  ...      NaN      NaN
# 3      3  6_Rahimzadeh_137covid_patient101_SR_4_IM00010.png  ...      NaN      NaN
# 4      4  6_Rahimzadeh_137covid_patient101_SR_4_IM00011.png  ...      NaN      NaN
#
# [5 rows x 45 columns]

# %%
df_meta_covid['Country'].unique()     # unique countries
# Out:
# array(['Iran', 'Italy', 'China', '-', 'Turkey', 'Ukraine', 'Belgium',
#        'South Korea', 'Taiwan', 'Spain', 'Portugal', 'Greece', 'Russia',
#        'Japan'], dtype=object)

# %%
df_meta_covid['Patient ID'].nunique() # number of unique patients
# Out:
# 464

# %% [markdown]
# ### Analysis of df_meta_normal

# %% [markdown]
# ## Split data into training, valdiation and test data

# %%
np.random.seed(42)

# Configuration of sizes
test_size = 0.1
validation_size = 0.1

# List of classes
classes_list = [('1NonCOVID','NonCOVID'), 
                ('2COVID','COVID'), 
                ('3CAP','CAP')]

# %%
# Get patient to image mappings

# Covid patients
covid_patient_to_image = df_meta_covid.groupby(['Patient ID'])['File name'].apply(list).reset_index()
# Normal patients
normal_patient_to_image = df_meta_normal.groupby(['Patient ID'])['File name'].apply(list).reset_index()
# CAP patients
cap_patient_to_image = df_meta_cap.groupby(['Patient ID'])['File name'].apply(list).reset_index()

# %%
def split_ids(patient_to_image, val_size, test_size):
  '''
  '''
  # Calculate the number of training, valdiation and test samples
  len_all = len(patient_to_image)
  nb_test = np.floor(len_all * test_size).astype('int')
  nb_val = np.floor(len_all * val_size).astype('int')
  nb_train = len_all - (nb_test + nb_val).astype('int')
  # Create sub-samples of patient_to_image
  patient_ids = patient_to_image.index.values
  train_ids = np.random.choice(patient_ids, nb_train, replace=False)
  val_ids = np.random.choice(list(set(patient_ids)-set(train_ids)), nb_val, 
                             replace=False)
  test_ids = np.random.choice(list(set(patient_ids)-set(train_ids)-set(val_ids)),
                              nb_test, replace = False)
  
  return train_ids, val_ids, test_ids

# %%
# Split data into training, validation and test subsets

sample_id_dict = {}

for _, cl_dest in classes_list:
  if cl_dest == 'COVID':
    # Split covid patients
    covid_train_ids, covid_val_ids, covid_test_ids = \
      split_ids(covid_patient_to_image, validation_size, test_size)
    
    # Add data to dictionary
    sample_id_dict[cl_dest] = {'IMG':covid_patient_to_image,
                               'TRAIN':covid_train_ids,
                               'VAL':covid_val_ids,
                               'TEST':covid_test_ids}
  elif cl_dest == 'NonCOVID':
    # Split normal patients
    norm_train_ids, norm_val_ids, norm_test_ids = \
      split_ids(normal_patient_to_image, validation_size, test_size)
    # Add data to dictionary
    sample_id_dict[cl_dest] = {'IMG':normal_patient_to_image,
                               'TRAIN':norm_train_ids,
                               'VAL':norm_val_ids,
                               'TEST':norm_test_ids}
  else: # CAP
    # Split cap patients
    cap_train_ids, cap_val_ids, cap_test_ids = \
      split_ids(cap_patient_to_image, validation_size, test_size)
    # Add data to dictionary
    sample_id_dict[cl_dest] = {'IMG':cap_patient_to_image,
                               'TRAIN':cap_train_ids,
                               'VAL':cap_val_ids,
                               'TEST':cap_test_ids}


#print(len(covid_train_ids), len(covid_val_ids), len(covid_test_ids))
#print(len(norm_train_ids), len(norm_val_ids), len(norm_test_ids))
#print(len(cap_train_ids), len(cap_val_ids), len(cap_test_ids))

# %%
# Create directories
source_dir = '/content/curated_data/curated_data/'
train_dir = str(source_dir + 'train/')
test_dir = str(source_dir + 'test/')
validation_dir = str(source_dir + 'validation/')
# !mkdir $train_dir
# !mkdir $test_dir
# !mkdir $validation_dir

# Create subdirectories for each class
for _, cl in classes_list:
  c_train = str(train_dir + cl)
  # !mkdir $c_train
  c_test = str(test_dir + cl)
  # !mkdir $c_test
  c_validation = str(validation_dir + cl)
  # !mkdir $c_validation

# %%
def move_files(patient_to_image, patient_ids, from_dir, to_dir):
  '''
  '''
  # Set a limit to mv-strings
  MAX_LEN = 20000

  # Check if at least one patient id was provided
  if len(patient_to_image) < 1:
    print('No files to move!')
    return None

  fs_to_move_stack = []
  fs_to_move = ''
  for id in patient_ids:
    file_names = f' {from_dir}'.join([fn for fn in patient_to_image.at[id,'File name']])
    # Extend fs_to_move by new file names and from_dir at the beginning
    fs_to_move = fs_to_move + f' {from_dir}' + file_names
    if len(fs_to_move) > MAX_LEN:
      fs_to_move_stack.append(fs_to_move)
      fs_to_move = ''
  # Append the last fs_to_move string to the file_stack
  fs_to_move_stack.append(fs_to_move)
  for fs_to_move in fs_to_move_stack:
    # !mv $fs_to_move $to_dir

# %%
# Move all data to new destinations
# %%time

for cl_src, cl_dest in classes_list:
  from_dir = source_dir + cl_src + '/'
  
  imgs = sample_id_dict[cl_dest]['IMG']

  # Move training data
  to_dir = train_dir + cl_dest
  ids = sample_id_dict[cl_dest]['TRAIN']
  move_files(imgs, ids, from_dir, to_dir)
  #print(to_dir)
  #print(len(ids))

  # Move validation data
  to_dir = validation_dir + cl_dest
  ids = sample_id_dict[cl_dest]['VAL']
  move_files(imgs, ids, from_dir, to_dir)
  #print(to_dir)
  #print(len(ids))

  # Move test data
  to_dir = test_dir + cl_dest
  ids = sample_id_dict[cl_dest]['TEST']
  move_files(imgs, ids, from_dir, to_dir)
  #print(to_dir)
  #print(len(ids))
# Out:
# CPU times: user 334 ms, sys: 480 ms, total: 814 ms
# Wall time: 6.95 s

# %% [markdown]
# # lightGBM

# %%
from timeit import default_timer as timer

# %%
import os
import cv2
import numpy as np

# %%
import glob
source_dir = '/content/curated_data/curated_data/'
train_dir = str(source_dir + 'train/')
test_dir = str(source_dir + 'test/')
validation_dir = str(source_dir + 'validation/')
data_format = '/*.png'

# %%
# !find '/content/curated_data/curated_data/test' -type f | wc -l
# Out:
# 1777

# %%
# !find '/content/curated_data/curated_data/train' -type f | wc -l
# Out:
# 13568

# %%
# !find '/content/curated_data/curated_data/validation' -type f | wc -l
# Out:
# 1759

# %%
#dict_case_df.keys()
dict_case_lst = ['NonCOVID', 'COVID', 'CAP']

# %% [markdown]
# ## train

# %%
def load_imagelist_label(dir):
  lgbm_list = []
  lgbm_label = []

  for case in dict_case_lst:#dict_case_df.keys():
    file_list = glob.glob(os.path.join(dir, case + data_format))
    
    for f in range(len(file_list)):  
      img = cv2.imread(file_list[f], cv2.IMREAD_GRAYSCALE)
      img = cv2.resize(img, (224, 224))
      lgbm_list.append(img)
      lgbm_label.append(case)

  return lgbm_list,lgbm_label    

lgbm_list,lgbm_label = load_imagelist_label(train_dir)

# %%
lgbm_array = np.array(lgbm_list)

# %%
lgbm_array.shape
# Out:
# (13568, 224, 224)

# %%
lgbm_array.shape
# Out:
# (13568, 224, 224)

# %%
lgbm_array = lgbm_array / 255.0

# %%
lgbm_array.shape
# Out:
# (13568, 224, 224)

# %%
lgbm_label = np.array(lgbm_label)

# %%
#from sklearn.linear_model import LogisticRegression

#clf = LogisticRegression(multi_class='ovr')

# %%
lgbm_array.reshape(lgbm_array.shape[0], -1).shape
# Out:
# (13568, 50176)

# %%
#clf.fit(lr_array.reshape(lr_array.shape[0], -1), lr_label)

# %% [markdown]
# ## fit

# %%
import lightgbm as lgb

#lgbm = lgb.LGBMClassifier(random_state=42)

# %%
from timeit import default_timer as timer
start = timer()

# %%
#from sklearn.model_selection import GridSearchCV

#lgbm = lgb.LGBMClassifier(**params,random_state=42)

#params = {"learning_rate": [0.01],#[0.01, 0.05, 0.1]
#          "num_leaves": [10],#[10, 20, 30]
#          "max_depth": [5],#[2, 5, 10]
#          "n_estimators": [50]}#[50, 100, 150]

#grid_search = GridSearchCV(lgbm, n_jobs=-1, param_grid=params, cv=3, scoring="neg_log_loss")
#grid_search.fit(lgbm_array.reshape(lgbm_array.shape[0], -1), lgbm_label)

# %%
#callbacks=[lgb.reset_parameter(learning_rate= lambda current_round: 0.1 * np.exp(-0.001 * current_round))]

# %%
#grid_search.best_params_

# %%
#grid_search.best_score_

# %%
#lgbm = grid_search.best_estimator_
#compute_logloss(lgbm, X_train, X_test, y_train, y_test)

# %%
params = {#'learning_rate': 0.05, 
          'max_depth': 5, 
          'num_leaves': 10, 
          'n_estimators': 97}
          #,'objective': 'binary'}

# %%
#lgbm.fit(lgbm_array.reshape(lgbm_array.shape[0], -1), lgbm_label,callbacks=[lgb.reset_parameter(learning_rate= lambda current_round: 0.1 * np.exp(-0.001 * current_round))])
lgbm = lgb.LGBMClassifier(**params,random_state=42)
lgbm.fit(lgbm_array.reshape(lgbm_array.shape[0], -1), lgbm_label)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=5,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=97, n_jobs=-1, num_leaves=10, objective=None,
#                random_state=42, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=42, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
end = timer()

print(f"Training LGBM took {end-start: .2f} seconds")
# Out:
# Training LGBM took  887.75 seconds

# %%
#shoud stop here,
#try train validat than test overriding variable memory removing

# %%
 y_pred = lgbm.predict(lgbm_array.reshape(lgbm_array.shape[0], -1))

# %%
y_pred
# Out:
# array(['NonCOVID', 'NonCOVID', 'NonCOVID', ..., 'CAP', 'CAP', 'CAP'],
#       dtype='<U8')

# %%
len(lgbm_label)
# Out:
# 13568

# %%
import sklearn.metrics as met
met.accuracy_score(lgbm_label, y_pred)
# Out:
# 0.9826061320754716

# %%
import sklearn.metrics as met
#def compute_logloss_train(model, X_train,y_train):
  
  #print(f"Log loss train set: {met.log_loss(y_train, model.predict_proba(X_train)[:,1]): .4f}")
  #print(f"Log loss test set: {met.log_loss(y_test, model.predict_proba(X_test)[:,1]): .4f}")

  ### martin add start
  #print("\n add by martin")
  #print(f"Training accuracy: \t{met.accuracy_score(y_train, model.predict(X_train)) : .4f}")
  #print(f"Test accuracy: \t\t{met.accuracy_score(y_test,  model.predict(X_test)): .4f}")

# %%
#compute_logloss_train(lgbm,lgbm_array.reshape(lgbm_array.shape[0], -1),lgbm_label)

# %%
y_train =  lgbm_label

# %% [markdown]
# ## test

# %%
test_dir
# Out:
# '/content/curated_data/curated_data/test/'

# %%
lgbm_list,lgbm_label = load_imagelist_label(test_dir)

# %%
lgbm_array_test = np.array(lgbm_list)

# %%
lgbm_array_test.shape
# Out:
# (1777, 224, 224)

# %%
lgbm_array_test = lgbm_array_test / 255.0

# %%
lgbm_array_test.shape
# Out:
# (1777, 224, 224)

# %%
lgbm_label_test = np.array(lgbm_label)

# %%
lgbm_array_test.reshape(lgbm_array_test.shape[0], -1).shape
# Out:
# (1777, 50176)

# %%
 y_pred_test = lgbm.predict(lgbm_array_test.reshape(lgbm_array_test.shape[0], -1))

# %%
met.accuracy_score(lgbm_label_test, y_pred_test)
# Out:
# 0.7456387169386607

# %% [markdown]
# ## validate

# %%
validation_dir
# Out:
# '/content/curated_data/curated_data/validation/'

# %%
lgbm_list,lgbm_label = load_imagelist_label(validation_dir)

# %%
lgbm_array_validation = np.array(lgbm_list)

# %%
lgbm_array_validation = lgbm_array_validation / 255.0

# %%
lgbm_label_validation = np.array(lgbm_label)

# %%
lgbm_array_validation.reshape(lgbm_array_validation.shape[0], -1).shape
# Out:
# (1759, 50176)

# %%
 y_pred_validation = lgbm.predict(lgbm_array_validation.reshape(lgbm_array_validation.shape[0], -1))

# %%
met.accuracy_score(lgbm_label_validation, y_pred_validation)
# Out:
# 0.763501989766913

# %%
import sklearn.metrics as met
def compute_logloss_train(model, X_train, X_test, y_train, y_test):
  
  print(f"Log loss train set: {met.log_loss(y_train, model.predict_proba(X_train)[:,1]): .4f}")
  print(f"Log loss test set: {met.log_loss(y_test, model.predict_proba(X_test)[:,1]): .4f}")

  ### martin add start
  print("\n add by martin")
  print(f"Training accuracy: \t{met.accuracy_score(y_train, model.predict(X_train)) : .4f}")
  print(f"Test accuracy: \t\t{met.accuracy_score(y_test,  model.predict(X_test)): .4f}")
  ### martin add stop

# %%
#compute_logloss(lgbm,lgbm_array.reshape(lr_array.shape[0], -1),lgbm_array_test.reshape(lgbm_array_test.shape[0], -1),lgbm_label,lgbm_label_test)

# %%
y_pred_train = lgbm.predict(lgbm_array.reshape(lgbm_array.shape[0], -1))
y_pred_test = lgbm.predict(lgbm_array_test.reshape(lgbm_array_test.shape[0], -1))
y_prob_train = lgbm.predict_proba(lgbm_array.reshape(lgbm_array.shape[0], -1))[:,1]
y_prob_test = lgbm.predict_proba(lgbm_array_test.reshape(lgbm_array_test.shape[0], -1))[:,1]

#print(f"Log loss training set: {met.log_loss(df_train['target'], y_prob_train)}")
#print(f"Log loss test set: {met.log_loss(df_test['target'], y_prob_test)}")

# %%
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import seaborn as sns
import pandas as pd

def plot_confusion_matrix_x(labels,predictions,classes_name):
  """
  example:
  predictions=max_predict # np.argmax(y_predict, axis=-1)
  labels=test_generator.classes
  classes_name = artist_list
  """
  con_mat = tf.math.confusion_matrix(labels=labels, predictions=predictions).numpy()
  con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)

  con_mat_df = pd.DataFrame(con_mat_norm,index = classes_name,columns = classes_name)

  figure = plt.figure(figsize=(8, 8))
  sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

# %%
lgbm_label_test
# Out:
# array(['NonCOVID', 'NonCOVID', 'NonCOVID', ..., 'CAP', 'CAP', 'CAP'],
#       dtype='<U8')

# %%
dict_case_lst
# Out:
# ['NonCOVID', 'COVID', 'CAP']

# %%
y_pred_test
# Out:
# array(['NonCOVID', 'NonCOVID', 'NonCOVID', ..., 'COVID', 'COVID', 'CAP'],
#       dtype='<U8')

# %%
from sklearn.metrics import classification_report
report = classification_report(lgbm_label_test, y_pred_test, target_names=dict_case_lst)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     NonCOVID       0.54      0.54      0.54       262
#        COVID       0.84      0.69      0.76       873
#          CAP       0.73      0.90      0.81       642
#
#     accuracy                           0.75      1777
#    macro avg       0.70      0.71      0.70      1777
# weighted avg       0.76      0.75      0.74      1777

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
plot_confusion_matrix(clf, lr_array.reshape(lr_array.shape[0], -1), lr_label, cmap=plt.cm.Blues, normalize='true')  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-46d04c2b5293> in <module>()
# ----> 1 plot_confusion_matrix(clf, lr_array.reshape(lr_array.shape[0], -1), lr_label, cmap=plt.cm.Blues, normalize='true')
#       2 plt.show()
#
# NameError: name 'clf' is not defined

# %%
plot_confusion_matrix(lgbm_label_test, y_pred_test, labels=dict_case_lst, cmap=plt.cm.Blues, normalize='true')  
plt.show()

# %%
plot_confusion_matrix_x(lgbm_label_test,y_pred_test,dict_case_lst)
